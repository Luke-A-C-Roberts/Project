# %%
from pandas import read_csv
from collections import Counter
import matplotlib.pyplot as plt
from seaborn import barplot

df = read_csv("NED_list.csv")

# %%
Counter(df["Requested"])
# Out:
# Counter({'S0': 12551,
#          'E': 7266,
#          'B': 6413,
#          'S0/a': 2576,
#          'AB': 2455,
#          'A': 2052})

# %%
barplot(Counter(df["Requested"]))
# Out:
# <AxesSubplot:>

# %%
barplot(Counter(df.where(df["Name"].str.contains("^NGC")).dropna()["Requested"]))
# Out:
# <AxesSubplot:>
