# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
from astropy.io import fits
from astroquery.ipac.ned import Ned
ned = Ned()

# %%
from inspect import getfullargspec

# %%
getfullargspec(ned.get_images)
# Out:
# FullArgSpec(args=['self', 'object_name'], varargs=None, varkw=None, defaults=None, kwonlyargs=['get_query_payload', 'show_progress'], kwonlydefaults={'get_query_payload': False, 'show_progress': True}, annotations={})

# %%
image = ned.get_images("MCG -01-35-002")

# %%
image = image[0][0]

# %%
image

# %%
plt.style.use(astropy_mpl_style)

# %%
image_data = image.data

# %%
image_data.shape
# Out:
# (141, 141)

# %%
plt.imshow(image_data)
plt.colorbar()

# %%
type(image_data)
# Out:
# numpy.ndarray

# %%
def get_image_data(object_name: str, ned: Ned) -> np.ndarray:
    return ned.get_images(object_name)[0][0].data

# %%
plt.imshow(get_image_data("NGC 5240", ned))

# %%
ned.get_table("NGC 5240")
# Out:
# <Table length=73>
#  No.   Observed Passband  ...      Comments
#                           ...
# int32        object       ...       object
# ----- ------------------- ... -----------------
#     1      FUV (GALEX) AB ... From new raw data
#     2      FUV (GALEX) AB ... From new raw data
#     3      FUV (GALEX) AB ... From new raw data
#     4      NUV (GALEX) AB ... From new raw data
#     5      NUV (GALEX) AB ... From new raw data
#     6      NUV (GALEX) AB ... From new raw data
#   ...                 ... ...               ...
#    68       HI 21 cm line ... From new raw data
#    69 HI 21 cm line (NRT) ... From new raw data
#    70   HI 21cm (ALFALFA) ... From new raw data
#    71       HI 21 cm line ... From new raw data
#    72       HI 21 cm line ... From new raw data
#    73     HI (21 cm line) ... From new raw data

# %%
from astroquery.ipac.ned import Conf
conf = Conf()

# %%
[*conf.keys()]
# Out:
# ['server',
#  'timeout',
#  'hubble_constant',
#  'correct_redshift',
#  'output_coordinate_frame',
#  'output_equinox',
#  'sort_output_by']

# %%
[*conf.values()]
# Out:
# [<ConfigItem: name='server' value='https://ned.ipac.caltech.edu/cgi-bin/' at 0x7f4a275ef5d0>,
#  <ConfigItem: name='timeout' value=60 at 0x7f4a275ef7d0>,
#  <ConfigItem: name='hubble_constant' value='73' at 0x7f4a275ef890>,
#  <ConfigItem: name='correct_redshift' value='1' at 0x7f4a275ef910>,
#  <ConfigItem: name='output_coordinate_frame' value='Equatorial' at 0x7f4a275efb50>,
#  <ConfigItem: name='output_equinox' value='J2000.0' at 0x7f4a275eff10>,
#  <ConfigItem: name='sort_output_by' value='RA or Longitude' at 0x7f4a275f0150>]

# %%
ned.query_object("m31")
# Out:
# <Table length=1>
#  No.  Object Name     RA     ... Redshift Points Diameter Points Associations
#                    degrees   ...
# int32    str30     float64   ...      int32           int32         int32
# ----- ----------- ---------- ... --------------- --------------- ------------
#     1 MESSIER 031   10.68479 ...              40              13            2

# %%
spectra = ned.get_spectra("m31")
