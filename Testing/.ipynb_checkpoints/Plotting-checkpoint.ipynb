# %%
import resnet
# Out:
# 2024-02-28 18:39:36.892281: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 18:39:36.928671: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
rn = resnet.resnet(34, 10)
# Out:
# ic| multilayer_spec: MultiLayerSpec(layer_specs=[LayerSpec(kernel_size=3, filters=64),
#                                                  LayerSpec(kernel_size=3, filters=64)],
#                                     repetitions=3)
# ic| multilayer_spec: MultiLayerSpec(layer_specs=[LayerSpec(kernel_size=3, filters=128),
#                                                  LayerSpec(kernel_size=3, filters=128)],
#                                     repetitions=4)
# ic| multilayer_spec: MultiLayerSpec(layer_specs=[LayerSpec(kernel_size=3, filters=256),
#                                                  LayerSpec(kernel_size=3, filters=256)],
#                                     repetitions=6)
# ic| multilayer_spec: MultiLayerSpec(layer_specs=[LayerSpec(kernel_size=3, filters=512),
#                                                  LayerSpec(kernel_size=3, filters=512)],
#                                     repetitions=3)

# %%
from keras.utils import plot_model

plot_model(rn, show_shapes=True)

# %%
from keras.applications import resnet
